# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = 'path/to/your/dataset'

# %%
import numpy as np
import pandas as pd
import random
import torch
import time
import datetime
import gc
from nltk.corpus import stopwords
import re

seed_val = 42
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)

# %%
df = pd.read_csv(path+"hotel_reviews.csv")
df.head()
# Out:
#                                               review  polarity   massimo
# 0                                            Nothing  Negative      fear
# 1   Room might feel a bit small over a longer sta...  Negative  negative
# 2                    Bad location difficult to reach  Negative      fear
# 3                                            Nothing  Negative      fear
# 4   Bedroom not clean rubbish still in the bin em...  Negative  negative

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#text preprocessing

sw = stopwords.words('english')

def clean_text(text):
    text = text.lower()
    text = re.sub(r"[^a-zA-Z?.!,¿]+", " ", text) # replacing everything with space except (a-z, A-Z, ".", "?", "!", ","
    text = re.sub(r"http\S+", "",text) #Removing URLs
    # Remove words with less than 3 letters
    text = re.sub(r'\b\w{1,2}\b', '', text)
    # Remove extra spaces caused by the removal
    text = re.sub(r'\s+', ' ', text).strip()

    html=re.compile(r'<.*?>')
    text = html.sub(r'',text) #Removing html tags
    punctuations = '@#!?+&*[]-%.:/();$=><|{}^' + "'`" + '_'
    for p in punctuations:
        text = text.replace(p,'') #Removing punctuations
    text = [word.lower() for word in text.split() if word.lower() not in sw]
    text = " ".join(text) #removing stopwords
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    text = emoji_pattern.sub(r'', text) #Removing emojis
    return text

df['text'] = df['review'].apply(lambda x: clean_text(x))
df.head()
# Out:
#                                               review  polarity   massimo  \
# 0                                            Nothing  Negative      fear
# 1   Room might feel a bit small over a longer sta...  Negative  negative
# 2                    Bad location difficult to reach  Negative      fear
# 3                                            Nothing  Negative      fear
# 4   Bedroom not clean rubbish still in the bin em...  Negative  negative
#
#                                                 text
# 0                                            nothing
# 1  room might feel bit small longer stay toilet s...
# 2                       bad location difficult reach
# 3                                            nothing
# 4  bedroom clean rubbish still bin empty shampoo ...

# %%
len(df)
# Out:
# 50000

# %%
# Filter out one-word documents
df = df[df['text'].str.split().apply(len) > 1]

# %%
df.head()
# Out:
#                                               review  polarity   massimo  \
# 1   Room might feel a bit small over a longer sta...  Negative  negative
# 2                    Bad location difficult to reach  Negative      fear
# 4   Bedroom not clean rubbish still in the bin em...  Negative  negative
# 5   I asked for a double bed and hot 2 singles pu...  Negative     anger
# 6   That guys are terrible Stuff is really greedy...  Negative     trust
#
#                                                 text
# 1  room might feel bit small longer stay toilet s...
# 2                       bad location difficult reach
# 4  bedroom clean rubbish still bin empty shampoo ...
# 5  asked double bed hot singles pushed together a...
# 6  guys terrible stuff really greedy poor beginin...

# %%
len(df)
# Out:
# 45850

# %%
df.to_csv(path+"hotel_revs_topic_model.csv", index=False)

# %%
# !pip install bertopic

# %%
#import dependencies

from bertopic import BERTopic
from sentence_transformers import SentenceTransformer, util
from umap import UMAP
from hdbscan import HDBSCAN
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.vectorizers import ClassTfidfTransformer

#Instantiating GPU device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

print(device)
# Out:
# cuda

# %%
num_neighbors = 15
min_clusters = 150

# %%
# Step 1 - Extract embeddings

#embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
embedding_model = SentenceTransformer('paraphrase-MPNet-base-v2')
#Move the model to GPU for speed
embedding_model.to(device)

# Step 2 - Reduce dimensionality
umap_model = UMAP(n_neighbors=num_neighbors, n_components=5, metric='cosine', min_dist=0, random_state=seed_val)

# Step 3 - Cluster reduced embeddings
hdbscan_model = HDBSCAN(min_cluster_size=min_clusters, metric='euclidean', cluster_selection_method='eom',
                                prediction_data=True)

# Step 4 - Tokenize topics
vectorizer_model = CountVectorizer()

# Step 5 - Create topic representation cTfIdf
ctfidf_model = ClassTfidfTransformer()

# %%
# All steps together

topic_model = BERTopic(n_gram_range=(1, 2),
  embedding_model=embedding_model,    # Step 1 - Extract embeddings
  umap_model=umap_model,              # Step 2 - Reduce dimensionality
  hdbscan_model=hdbscan_model,        # Step 3 - Cluster reduced embeddings
  vectorizer_model=vectorizer_model,  # Step 4 - Tokenize topics
  ctfidf_model=ctfidf_model,          # Step 5 - Extract topic words
  calculate_probabilities=True,
  nr_topics=20,                       # define nr topics (optional)
  verbose=True)

# %%
#topic modeling for reviews
reviews = df['text'].to_list()
topics, probs = topic_model.fit_transform(reviews)
topic_model.save(path + "Selected_TM_10_v2")
# topic_model = BERTopic.load(path+"Bert_explanability/Selected_TM_10")

# topic_model= topic_model.load(path + "Bert_explanability/Selected_TM_10_v2")
# topic_model= BERTopic.load(path + "Selected_TM_10_v2")

# %%
titles_df = pd.read_csv(path+"titles10.csv")
titles_df
# Out:
#     Topic Number                                          Top_words  \
# 0              0  [hotel, staff, location, clean, friendly, grea...
# 1              1  [shower, bathroom, pool, room, bath, water, sm...
# 2              2  [breakfast, staff, good, excellent, great, fri...
# 3              3  [staff, friendly, helpful, location, great, ex...
# 4              4  [bed, beds, comfortable, pillows, comfy, room,...
# 5              5  [location, station, close, great, metro, city,...
# 6              6  [room, hotel, booking, check, one, told, recep...
# 7              7  [nothing, everything, anything, perfect, think...
# 8              8  [breakfast, expensive, included, price, food, ...
# 9              9  [air, conditioning, hot, fridge, room, cold, w...
# 10            10  [small, room, rooms, dark, bit, light, little,...
# 11            11  [wifi, internet, slow, free, connection, poor,...
# 12            12  [noisy, noise, hear, night, street, room, outs...
# 13            13  [coffee, tea, kettle, milk, making, facilities...
# 14            14  [parking, car, park, expensive, hotel, free, d...
# 15            15  [lift, elevator, lifts, stairs, slow, elevator...
# 16            16  [price, expensive, value, money, bit, high, pr...
# 17            17  [birthday, cake, special, champagne, staff, ma...
# 18            18  [bar, drinks, prices, expensive, drink, price,...
#
#                               title  \
# 0            Hospitality Excellence
# 1            Relaxing Water Retreat
# 2   Hospitality Excellence Location
# 3        Welcoming Staff Experience
# 4                Cozy Bedding Haven
# 5               Urban Transport Hub
# 6               Hotel Booking Check
# 7        Perfect Everything Thought
# 8       Luxury Breakfast Experience
# 9              Room Climate Control
# 10               Cozy Room Lighting
# 11       Internet Connection Issues
# 12            Urban Noise Pollution
# 13       Beverage Making Facilities
# 14              Hotel Parking Costs
# 15       Efficient Elevator Systems
# 16          Costly Value Perception
# 17         Celebratory Sweet Treats
# 18                 Bar Drink Prices
#
#                                           description
# 0   Warm, clean, and helpful service in a great lo...
# 1   Escape to a serene oasis with luxurious amenit...
# 2   Great staff, excellent service, and nice bar i...
# 3   Positive interactions with staff, great locati...
# 4   Experience comfort with plush pillows and cozy...
# 5   City station with great metro and train connec...
# 6   Manage hotel reservations efficiently with sta...
# 7   Exploring perfection, thoughts, and dislikes i...
# 8   Indulge in lavish morning meals with gourmet o...
# 9   Manage room temperature with air conditioning,...
# 10  Small, dark rooms with light, little lighting ...
# 11  Problems with wifi, slow internet, poor signal...
# 12  Sounds of city life: streets, rooms, night, an...
# 13  Room with coffee, tea, milk, kettle, cups, and...
# 14  Exploring expensive hotel parking options and ...
# 15  Enhancing building vertical transportation wit...
# 16  Exploring perceptions of cost, value, and pric...
# 17  Indulge in delightful birthday cake, champagne...
# 18  Exploring expensive wine, beer, and mini bar c...
